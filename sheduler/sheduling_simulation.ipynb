# %%
from collections import deque

import pandas as pd
from IPython.display import display


def round_robin_scheduling(processes, time_quantum=1):
    # Sort processes by their arrival time
    processes.sort(key=lambda x: x[1])

    # Initialize variables
    current_time = 1
    queue = deque()
    timeline = []
    waiting_time = {process[0]: 0 for process in processes}
    turnaround_time = {process[0]: 0 for process in processes}
    remaining_burst_time = {process[0]: process[2] for process in processes}
    arrival_time = {process[0]: process[1] for process in processes}

    # Start the round-robin scheduling
    while processes or queue:
        # Add initially arrived processes to the queue
        while processes and processes[0][1] <= current_time:
            process_id, _, _ = processes.pop(0)
            queue.append(process_id)

        if queue:
            process_id = queue.popleft()

            # Execute the process
            exec_time = min(time_quantum, remaining_burst_time[process_id])
            remaining_burst_time[process_id] -= exec_time
            timeline.append((process_id, current_time - exec_time, current_time))
            current_time += exec_time

            # Update waiting time for other processes
            for pid in queue:
                waiting_time[pid] += exec_time

            # Check if the process needs more time
            if remaining_burst_time[process_id] > 0:
                queue.append(process_id)

            # Update turnaround time
            if remaining_burst_time[process_id] == 0:
                turnaround_time[process_id] = current_time - arrival_time[process_id]

        else:
            # If no process is running and processes are pending, advance time
            if processes:
                current_time = processes[0][1]

    # Calculate average waiting and turnaround times
    average_waiting_time = sum(waiting_time.values()) / len(waiting_time) if len(waiting_time) > 0 else 0
    average_turnaround_time = sum(turnaround_time.values()) / len(turnaround_time) if len(turnaround_time) > 0 else 0

    # Return the results
    return timeline, waiting_time, turnaround_time, average_waiting_time, average_turnaround_time


def display_round_robin_results(processes, time_quantum):
    """
    Display the timeline of RR
    :param processes:
    :param time_quantum:
    :return:
    """
    timeline, waiting_time, turnaround_time, _, _ = round_robin_scheduling(processes, time_quantum)

    # Set pandas display options
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)

    # Create DataFrames for visualization
    df_timeline = pd.DataFrame(timeline, columns=["ProcessID", "StartTime", "EndTime"])
    df_waiting_turnaround = pd.DataFrame(list(waiting_time.items()), columns=["ProcessID", "WaitingTime"])
    df_waiting_turnaround["TurnaroundTime"] = df_waiting_turnaround["ProcessID"].map(turnaround_time)

    # Define the maximum time units for the table
    max_time_units = timeline[-1][2]

    # Initialize the table with empty strings
    execution_table = {process_id: [" " for _ in range(max_time_units)] for process_id in waiting_time}

    # Fill the table with 'X' where processes are executing
    for process_id, start, end in timeline:
        for time_unit in range(start, min(end, max_time_units)):
            execution_table[process_id][time_unit] = "X"

    # Convert the table to a DataFrame for better visualization
    df_execution_table = pd.DataFrame(execution_table)
    df_execution_table.index += 1  # Adjusting index to start from 1
    df_execution_table.columns.name = "ProcessID"

    # Transpose the DataFrame to swap rows and columns
    df_execution_transposed = df_execution_table.transpose()

    # Extract unique process IDs from timeline in the order they first appear
    ordered_process_ids = []
    for process_id, _, _ in timeline:
        if process_id not in ordered_process_ids:
            ordered_process_ids.append(process_id)
    ordered_process_ids = sorted(ordered_process_ids)
    # Reordering the DataFrame to display processes in the order they appear in timeline
    df_execution_ordered = df_execution_transposed.reindex(ordered_process_ids)

    # Styling and displaying the DataFrame directly
    styled_df = df_execution_ordered.style.map(
    lambda x: 'background-color: lightgreen' if x == 'X' else 'background-color: white')
    display(styled_df)


def main():
    # User input for processes and time quantum
    processes = [("A", 4, 3), ("B", 3, 7), ("C", 1, 4), ("D", 5, 2), ("E", 0, 2), ("F", 2, 4)]  # example
    processes_exe = [("A", 4, 4), ("B", 3, 3), ("C", 0, 2), ("D", 2, 7), ("E", 5, 2), ("F", 1, 4)]  # exercise
    processes_test = [("A", 3, 4), ("B", 2, 2), ("C", 5, 7), ("D", 4, 2), ("E", 0, 3), ("F", 1, 4)] #test
    display_round_robin_results(processes, 1)
    display_round_robin_results(processes_exe, 1)
    display_round_robin_results(processes_test, 1)



if __name__ == '__main__':
    main()
# Out:
# <style type="text/css">
# #T_014b7_row0_col0, #T_014b7_row0_col1, #T_014b7_row0_col2, #T_014b7_row0_col3, #T_014b7_row0_col4, #T_014b7_row0_col5, #T_014b7_row0_col7, #T_014b7_row0_col8, #T_014b7_row0_col9, #T_014b7_row0_col10, #T_014b7_row0_col12, #T_014b7_row0_col13, #T_014b7_row0_col14, #T_014b7_row0_col15, #T_014b7_row0_col17, #T_014b7_row0_col18, #T_014b7_row0_col19, #T_014b7_row0_col20, #T_014b7_row0_col21, #T_014b7_row1_col0, #T_014b7_row1_col1, #T_014b7_row1_col2, #T_014b7_row1_col3, #T_014b7_row1_col4, #T_014b7_row1_col6, #T_014b7_row1_col7, #T_014b7_row1_col8, #T_014b7_row1_col9, #T_014b7_row1_col11, #T_014b7_row1_col12, #T_014b7_row1_col13, #T_014b7_row1_col14, #T_014b7_row1_col16, #T_014b7_row1_col17, #T_014b7_row2_col0, #T_014b7_row2_col2, #T_014b7_row2_col3, #T_014b7_row2_col5, #T_014b7_row2_col6, #T_014b7_row2_col7, #T_014b7_row2_col8, #T_014b7_row2_col10, #T_014b7_row2_col11, #T_014b7_row2_col12, #T_014b7_row2_col13, #T_014b7_row2_col15, #T_014b7_row2_col16, #T_014b7_row2_col17, #T_014b7_row2_col18, #T_014b7_row2_col19, #T_014b7_row2_col20, #T_014b7_row2_col21, #T_014b7_row3_col0, #T_014b7_row3_col1, #T_014b7_row3_col2, #T_014b7_row3_col3, #T_014b7_row3_col4, #T_014b7_row3_col5, #T_014b7_row3_col6, #T_014b7_row3_col7, #T_014b7_row3_col9, #T_014b7_row3_col10, #T_014b7_row3_col11, #T_014b7_row3_col12, #T_014b7_row3_col14, #T_014b7_row3_col15, #T_014b7_row3_col16, #T_014b7_row3_col17, #T_014b7_row3_col18, #T_014b7_row3_col19, #T_014b7_row3_col20, #T_014b7_row3_col21, #T_014b7_row4_col1, #T_014b7_row4_col3, #T_014b7_row4_col4, #T_014b7_row4_col5, #T_014b7_row4_col6, #T_014b7_row4_col7, #T_014b7_row4_col8, #T_014b7_row4_col9, #T_014b7_row4_col10, #T_014b7_row4_col11, #T_014b7_row4_col12, #T_014b7_row4_col13, #T_014b7_row4_col14, #T_014b7_row4_col15, #T_014b7_row4_col16, #T_014b7_row4_col17, #T_014b7_row4_col18, #T_014b7_row4_col19, #T_014b7_row4_col20, #T_014b7_row4_col21, #T_014b7_row5_col0, #T_014b7_row5_col1, #T_014b7_row5_col2, #T_014b7_row5_col4, #T_014b7_row5_col5, #T_014b7_row5_col6, #T_014b7_row5_col8, #T_014b7_row5_col9, #T_014b7_row5_col10, #T_014b7_row5_col11, #T_014b7_row5_col13, #T_014b7_row5_col14, #T_014b7_row5_col15, #T_014b7_row5_col16, #T_014b7_row5_col18, #T_014b7_row5_col19, #T_014b7_row5_col20, #T_014b7_row5_col21 {
#   background-color: white;
# }
# #T_014b7_row0_col6, #T_014b7_row0_col11, #T_014b7_row0_col16, #T_014b7_row1_col5, #T_014b7_row1_col10, #T_014b7_row1_col15, #T_014b7_row1_col18, #T_014b7_row1_col19, #T_014b7_row1_col20, #T_014b7_row1_col21, #T_014b7_row2_col1, #T_014b7_row2_col4, #T_014b7_row2_col9, #T_014b7_row2_col14, #T_014b7_row3_col8, #T_014b7_row3_col13, #T_014b7_row4_col0, #T_014b7_row4_col2, #T_014b7_row5_col3, #T_014b7_row5_col7, #T_014b7_row5_col12, #T_014b7_row5_col17 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_014b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_014b7_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_014b7_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_014b7_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_014b7_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_014b7_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_014b7_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_014b7_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_014b7_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_014b7_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_014b7_level0_col9" class="col_heading level0 col9" >10</th>
#       <th id="T_014b7_level0_col10" class="col_heading level0 col10" >11</th>
#       <th id="T_014b7_level0_col11" class="col_heading level0 col11" >12</th>
#       <th id="T_014b7_level0_col12" class="col_heading level0 col12" >13</th>
#       <th id="T_014b7_level0_col13" class="col_heading level0 col13" >14</th>
#       <th id="T_014b7_level0_col14" class="col_heading level0 col14" >15</th>
#       <th id="T_014b7_level0_col15" class="col_heading level0 col15" >16</th>
#       <th id="T_014b7_level0_col16" class="col_heading level0 col16" >17</th>
#       <th id="T_014b7_level0_col17" class="col_heading level0 col17" >18</th>
#       <th id="T_014b7_level0_col18" class="col_heading level0 col18" >19</th>
#       <th id="T_014b7_level0_col19" class="col_heading level0 col19" >20</th>
#       <th id="T_014b7_level0_col20" class="col_heading level0 col20" >21</th>
#       <th id="T_014b7_level0_col21" class="col_heading level0 col21" >22</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ProcessID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_014b7_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_014b7_row0_col0" class="data row0 col0" > </td>
#       <td id="T_014b7_row0_col1" class="data row0 col1" > </td>
#       <td id="T_014b7_row0_col2" class="data row0 col2" > </td>
#       <td id="T_014b7_row0_col3" class="data row0 col3" > </td>
#       <td id="T_014b7_row0_col4" class="data row0 col4" > </td>
#       <td id="T_014b7_row0_col5" class="data row0 col5" > </td>
#       <td id="T_014b7_row0_col6" class="data row0 col6" >X</td>
#       <td id="T_014b7_row0_col7" class="data row0 col7" > </td>
#       <td id="T_014b7_row0_col8" class="data row0 col8" > </td>
#       <td id="T_014b7_row0_col9" class="data row0 col9" > </td>
#       <td id="T_014b7_row0_col10" class="data row0 col10" > </td>
#       <td id="T_014b7_row0_col11" class="data row0 col11" >X</td>
#       <td id="T_014b7_row0_col12" class="data row0 col12" > </td>
#       <td id="T_014b7_row0_col13" class="data row0 col13" > </td>
#       <td id="T_014b7_row0_col14" class="data row0 col14" > </td>
#       <td id="T_014b7_row0_col15" class="data row0 col15" > </td>
#       <td id="T_014b7_row0_col16" class="data row0 col16" >X</td>
#       <td id="T_014b7_row0_col17" class="data row0 col17" > </td>
#       <td id="T_014b7_row0_col18" class="data row0 col18" > </td>
#       <td id="T_014b7_row0_col19" class="data row0 col19" > </td>
#       <td id="T_014b7_row0_col20" class="data row0 col20" > </td>
#       <td id="T_014b7_row0_col21" class="data row0 col21" > </td>
#     </tr>
#     <tr>
#       <th id="T_014b7_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_014b7_row1_col0" class="data row1 col0" > </td>
#       <td id="T_014b7_row1_col1" class="data row1 col1" > </td>
#       <td id="T_014b7_row1_col2" class="data row1 col2" > </td>
#       <td id="T_014b7_row1_col3" class="data row1 col3" > </td>
#       <td id="T_014b7_row1_col4" class="data row1 col4" > </td>
#       <td id="T_014b7_row1_col5" class="data row1 col5" >X</td>
#       <td id="T_014b7_row1_col6" class="data row1 col6" > </td>
#       <td id="T_014b7_row1_col7" class="data row1 col7" > </td>
#       <td id="T_014b7_row1_col8" class="data row1 col8" > </td>
#       <td id="T_014b7_row1_col9" class="data row1 col9" > </td>
#       <td id="T_014b7_row1_col10" class="data row1 col10" >X</td>
#       <td id="T_014b7_row1_col11" class="data row1 col11" > </td>
# <style type="text/css">
# #T_95102_row0_col0, #T_95102_row0_col1, #T_95102_row0_col2, #T_95102_row0_col3, #T_95102_row0_col4, #T_95102_row0_col5, #T_95102_row0_col7, #T_95102_row0_col8, #T_95102_row0_col9, #T_95102_row0_col10, #T_95102_row0_col12, #T_95102_row0_col13, #T_95102_row0_col14, #T_95102_row0_col15, #T_95102_row0_col17, #T_95102_row0_col19, #T_95102_row0_col20, #T_95102_row0_col21, #T_95102_row1_col0, #T_95102_row1_col1, #T_95102_row1_col2, #T_95102_row1_col3, #T_95102_row1_col4, #T_95102_row1_col6, #T_95102_row1_col7, #T_95102_row1_col8, #T_95102_row1_col9, #T_95102_row1_col11, #T_95102_row1_col12, #T_95102_row1_col13, #T_95102_row1_col14, #T_95102_row1_col16, #T_95102_row1_col17, #T_95102_row1_col18, #T_95102_row1_col19, #T_95102_row1_col20, #T_95102_row1_col21, #T_95102_row2_col1, #T_95102_row2_col3, #T_95102_row2_col4, #T_95102_row2_col5, #T_95102_row2_col6, #T_95102_row2_col7, #T_95102_row2_col8, #T_95102_row2_col9, #T_95102_row2_col10, #T_95102_row2_col11, #T_95102_row2_col12, #T_95102_row2_col13, #T_95102_row2_col14, #T_95102_row2_col15, #T_95102_row2_col16, #T_95102_row2_col17, #T_95102_row2_col18, #T_95102_row2_col19, #T_95102_row2_col20, #T_95102_row2_col21, #T_95102_row3_col0, #T_95102_row3_col1, #T_95102_row3_col2, #T_95102_row3_col4, #T_95102_row3_col5, #T_95102_row3_col6, #T_95102_row3_col8, #T_95102_row3_col9, #T_95102_row3_col10, #T_95102_row3_col11, #T_95102_row3_col13, #T_95102_row3_col14, #T_95102_row3_col15, #T_95102_row3_col16, #T_95102_row3_col18, #T_95102_row4_col0, #T_95102_row4_col1, #T_95102_row4_col2, #T_95102_row4_col3, #T_95102_row4_col4, #T_95102_row4_col5, #T_95102_row4_col6, #T_95102_row4_col7, #T_95102_row4_col9, #T_95102_row4_col10, #T_95102_row4_col11, #T_95102_row4_col12, #T_95102_row4_col14, #T_95102_row4_col15, #T_95102_row4_col16, #T_95102_row4_col17, #T_95102_row4_col18, #T_95102_row4_col19, #T_95102_row4_col20, #T_95102_row4_col21, #T_95102_row5_col0, #T_95102_row5_col2, #T_95102_row5_col3, #T_95102_row5_col5, #T_95102_row5_col6, #T_95102_row5_col7, #T_95102_row5_col8, #T_95102_row5_col10, #T_95102_row5_col11, #T_95102_row5_col12, #T_95102_row5_col13, #T_95102_row5_col15, #T_95102_row5_col16, #T_95102_row5_col17, #T_95102_row5_col18, #T_95102_row5_col19, #T_95102_row5_col20, #T_95102_row5_col21 {
#   background-color: white;
# }
# #T_95102_row0_col6, #T_95102_row0_col11, #T_95102_row0_col16, #T_95102_row0_col18, #T_95102_row1_col5, #T_95102_row1_col10, #T_95102_row1_col15, #T_95102_row2_col0, #T_95102_row2_col2, #T_95102_row3_col3, #T_95102_row3_col7, #T_95102_row3_col12, #T_95102_row3_col17, #T_95102_row3_col19, #T_95102_row3_col20, #T_95102_row3_col21, #T_95102_row4_col8, #T_95102_row4_col13, #T_95102_row5_col1, #T_95102_row5_col4, #T_95102_row5_col9, #T_95102_row5_col14 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_95102">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95102_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_95102_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_95102_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_95102_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_95102_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_95102_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_95102_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_95102_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_95102_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_95102_level0_col9" class="col_heading level0 col9" >10</th>
#       <th id="T_95102_level0_col10" class="col_heading level0 col10" >11</th>
#       <th id="T_95102_level0_col11" class="col_heading level0 col11" >12</th>
#       <th id="T_95102_level0_col12" class="col_heading level0 col12" >13</th>
#       <th id="T_95102_level0_col13" class="col_heading level0 col13" >14</th>
#       <th id="T_95102_level0_col14" class="col_heading level0 col14" >15</th>
#       <th id="T_95102_level0_col15" class="col_heading level0 col15" >16</th>
#       <th id="T_95102_level0_col16" class="col_heading level0 col16" >17</th>
#       <th id="T_95102_level0_col17" class="col_heading level0 col17" >18</th>
#       <th id="T_95102_level0_col18" class="col_heading level0 col18" >19</th>
#       <th id="T_95102_level0_col19" class="col_heading level0 col19" >20</th>
#       <th id="T_95102_level0_col20" class="col_heading level0 col20" >21</th>
#       <th id="T_95102_level0_col21" class="col_heading level0 col21" >22</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ProcessID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95102_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_95102_row0_col0" class="data row0 col0" > </td>
#       <td id="T_95102_row0_col1" class="data row0 col1" > </td>
#       <td id="T_95102_row0_col2" class="data row0 col2" > </td>
#       <td id="T_95102_row0_col3" class="data row0 col3" > </td>
#       <td id="T_95102_row0_col4" class="data row0 col4" > </td>
#       <td id="T_95102_row0_col5" class="data row0 col5" > </td>
#       <td id="T_95102_row0_col6" class="data row0 col6" >X</td>
#       <td id="T_95102_row0_col7" class="data row0 col7" > </td>
#       <td id="T_95102_row0_col8" class="data row0 col8" > </td>
#       <td id="T_95102_row0_col9" class="data row0 col9" > </td>
#       <td id="T_95102_row0_col10" class="data row0 col10" > </td>
#       <td id="T_95102_row0_col11" class="data row0 col11" >X</td>
#       <td id="T_95102_row0_col12" class="data row0 col12" > </td>
#       <td id="T_95102_row0_col13" class="data row0 col13" > </td>
#       <td id="T_95102_row0_col14" class="data row0 col14" > </td>
#       <td id="T_95102_row0_col15" class="data row0 col15" > </td>
#       <td id="T_95102_row0_col16" class="data row0 col16" >X</td>
#       <td id="T_95102_row0_col17" class="data row0 col17" > </td>
#       <td id="T_95102_row0_col18" class="data row0 col18" >X</td>
#       <td id="T_95102_row0_col19" class="data row0 col19" > </td>
#       <td id="T_95102_row0_col20" class="data row0 col20" > </td>
#       <td id="T_95102_row0_col21" class="data row0 col21" > </td>
#     </tr>
#     <tr>
#       <th id="T_95102_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_95102_row1_col0" class="data row1 col0" > </td>
#       <td id="T_95102_row1_col1" class="data row1 col1" > </td>
#       <td id="T_95102_row1_col2" class="data row1 col2" > </td>
#       <td id="T_95102_row1_col3" class="data row1 col3" > </td>
#       <td id="T_95102_row1_col4" class="data row1 col4" > </td>
#       <td id="T_95102_row1_col5" class="data row1 col5" >X</td>
#       <td id="T_95102_row1_col6" class="data row1 col6" > </td>
#       <td id="T_95102_row1_col7" class="data row1 col7" > </td>
#       <td id="T_95102_row1_col8" class="data row1 col8" > </td>
#       <td id="T_95102_row1_col9" class="data row1 col9" > </td>
#       <td id="T_95102_row1_col10" class="data row1 col10" >X</td>
#       <td id="T_95102_row1_col11" class="data row1 col11" > </td>
# <style type="text/css">
# #T_92e80_row0_col0, #T_92e80_row0_col1, #T_92e80_row0_col2, #T_92e80_row0_col3, #T_92e80_row0_col4, #T_92e80_row0_col6, #T_92e80_row0_col7, #T_92e80_row0_col8, #T_92e80_row0_col9, #T_92e80_row0_col10, #T_92e80_row0_col12, #T_92e80_row0_col13, #T_92e80_row0_col14, #T_92e80_row0_col16, #T_92e80_row0_col18, #T_92e80_row0_col19, #T_92e80_row0_col20, #T_92e80_row0_col21, #T_92e80_row1_col0, #T_92e80_row1_col1, #T_92e80_row1_col2, #T_92e80_row1_col4, #T_92e80_row1_col5, #T_92e80_row1_col6, #T_92e80_row1_col7, #T_92e80_row1_col9, #T_92e80_row1_col10, #T_92e80_row1_col11, #T_92e80_row1_col12, #T_92e80_row1_col13, #T_92e80_row1_col14, #T_92e80_row1_col15, #T_92e80_row1_col16, #T_92e80_row1_col17, #T_92e80_row1_col18, #T_92e80_row1_col19, #T_92e80_row1_col20, #T_92e80_row1_col21, #T_92e80_row2_col0, #T_92e80_row2_col1, #T_92e80_row2_col2, #T_92e80_row2_col3, #T_92e80_row2_col4, #T_92e80_row2_col5, #T_92e80_row2_col6, #T_92e80_row2_col7, #T_92e80_row2_col8, #T_92e80_row2_col10, #T_92e80_row2_col11, #T_92e80_row2_col12, #T_92e80_row2_col14, #T_92e80_row2_col15, #T_92e80_row2_col17, #T_92e80_row3_col0, #T_92e80_row3_col1, #T_92e80_row3_col2, #T_92e80_row3_col3, #T_92e80_row3_col4, #T_92e80_row3_col5, #T_92e80_row3_col6, #T_92e80_row3_col8, #T_92e80_row3_col9, #T_92e80_row3_col10, #T_92e80_row3_col11, #T_92e80_row3_col13, #T_92e80_row3_col14, #T_92e80_row3_col15, #T_92e80_row3_col16, #T_92e80_row3_col17, #T_92e80_row3_col18, #T_92e80_row3_col19, #T_92e80_row3_col20, #T_92e80_row3_col21, #T_92e80_row4_col1, #T_92e80_row4_col3, #T_92e80_row4_col4, #T_92e80_row4_col5, #T_92e80_row4_col7, #T_92e80_row4_col8, #T_92e80_row4_col9, #T_92e80_row4_col10, #T_92e80_row4_col11, #T_92e80_row4_col12, #T_92e80_row4_col13, #T_92e80_row4_col14, #T_92e80_row4_col15, #T_92e80_row4_col16, #T_92e80_row4_col17, #T_92e80_row4_col18, #T_92e80_row4_col19, #T_92e80_row4_col20, #T_92e80_row4_col21, #T_92e80_row5_col0, #T_92e80_row5_col2, #T_92e80_row5_col3, #T_92e80_row5_col5, #T_92e80_row5_col6, #T_92e80_row5_col7, #T_92e80_row5_col8, #T_92e80_row5_col9, #T_92e80_row5_col11, #T_92e80_row5_col12, #T_92e80_row5_col13, #T_92e80_row5_col15, #T_92e80_row5_col16, #T_92e80_row5_col17, #T_92e80_row5_col18, #T_92e80_row5_col19, #T_92e80_row5_col20, #T_92e80_row5_col21 {
#   background-color: white;
# }
# #T_92e80_row0_col5, #T_92e80_row0_col11, #T_92e80_row0_col15, #T_92e80_row0_col17, #T_92e80_row1_col3, #T_92e80_row1_col8, #T_92e80_row2_col9, #T_92e80_row2_col13, #T_92e80_row2_col16, #T_92e80_row2_col18, #T_92e80_row2_col19, #T_92e80_row2_col20, #T_92e80_row2_col21, #T_92e80_row3_col7, #T_92e80_row3_col12, #T_92e80_row4_col0, #T_92e80_row4_col2, #T_92e80_row4_col6, #T_92e80_row5_col1, #T_92e80_row5_col4, #T_92e80_row5_col10, #T_92e80_row5_col14 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_92e80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92e80_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_92e80_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_92e80_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_92e80_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_92e80_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_92e80_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_92e80_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_92e80_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_92e80_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_92e80_level0_col9" class="col_heading level0 col9" >10</th>
#       <th id="T_92e80_level0_col10" class="col_heading level0 col10" >11</th>
#       <th id="T_92e80_level0_col11" class="col_heading level0 col11" >12</th>
#       <th id="T_92e80_level0_col12" class="col_heading level0 col12" >13</th>
#       <th id="T_92e80_level0_col13" class="col_heading level0 col13" >14</th>
#       <th id="T_92e80_level0_col14" class="col_heading level0 col14" >15</th>
#       <th id="T_92e80_level0_col15" class="col_heading level0 col15" >16</th>
#       <th id="T_92e80_level0_col16" class="col_heading level0 col16" >17</th>
#       <th id="T_92e80_level0_col17" class="col_heading level0 col17" >18</th>
#       <th id="T_92e80_level0_col18" class="col_heading level0 col18" >19</th>
#       <th id="T_92e80_level0_col19" class="col_heading level0 col19" >20</th>
#       <th id="T_92e80_level0_col20" class="col_heading level0 col20" >21</th>
#       <th id="T_92e80_level0_col21" class="col_heading level0 col21" >22</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ProcessID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92e80_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_92e80_row0_col0" class="data row0 col0" > </td>
#       <td id="T_92e80_row0_col1" class="data row0 col1" > </td>
#       <td id="T_92e80_row0_col2" class="data row0 col2" > </td>
#       <td id="T_92e80_row0_col3" class="data row0 col3" > </td>
#       <td id="T_92e80_row0_col4" class="data row0 col4" > </td>
#       <td id="T_92e80_row0_col5" class="data row0 col5" >X</td>
#       <td id="T_92e80_row0_col6" class="data row0 col6" > </td>
#       <td id="T_92e80_row0_col7" class="data row0 col7" > </td>
#       <td id="T_92e80_row0_col8" class="data row0 col8" > </td>
#       <td id="T_92e80_row0_col9" class="data row0 col9" > </td>
#       <td id="T_92e80_row0_col10" class="data row0 col10" > </td>
#       <td id="T_92e80_row0_col11" class="data row0 col11" >X</td>
#       <td id="T_92e80_row0_col12" class="data row0 col12" > </td>
#       <td id="T_92e80_row0_col13" class="data row0 col13" > </td>
#       <td id="T_92e80_row0_col14" class="data row0 col14" > </td>
#       <td id="T_92e80_row0_col15" class="data row0 col15" >X</td>
#       <td id="T_92e80_row0_col16" class="data row0 col16" > </td>
#       <td id="T_92e80_row0_col17" class="data row0 col17" >X</td>
#       <td id="T_92e80_row0_col18" class="data row0 col18" > </td>
#       <td id="T_92e80_row0_col19" class="data row0 col19" > </td>
#       <td id="T_92e80_row0_col20" class="data row0 col20" > </td>
#       <td id="T_92e80_row0_col21" class="data row0 col21" > </td>
#     </tr>
#     <tr>
#       <th id="T_92e80_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_92e80_row1_col0" class="data row1 col0" > </td>
#       <td id="T_92e80_row1_col1" class="data row1 col1" > </td>
#       <td id="T_92e80_row1_col2" class="data row1 col2" > </td>
#       <td id="T_92e80_row1_col3" class="data row1 col3" >X</td>
#       <td id="T_92e80_row1_col4" class="data row1 col4" > </td>
#       <td id="T_92e80_row1_col5" class="data row1 col5" > </td>
#       <td id="T_92e80_row1_col6" class="data row1 col6" > </td>
#       <td id="T_92e80_row1_col7" class="data row1 col7" > </td>
#       <td id="T_92e80_row1_col8" class="data row1 col8" >X</td>
#       <td id="T_92e80_row1_col9" class="data row1 col9" > </td>
#       <td id="T_92e80_row1_col10" class="data row1 col10" > </td>
#       <td id="T_92e80_row1_col11" class="data row1 col11" > </td>
